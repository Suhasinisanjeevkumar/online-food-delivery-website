# %%
import sqlite3

# %%
conn = sqlite3.connect('food_delivery.db')
cur=conn.cursor()

# %%
print(cur.execute("select * from restaurants").fetchall())
# Out:
# [(1, 'North Indian Dhaba', 1, 'Authentic North Indian meals', '123 Main St', '555-0101', 4.5, '/static/images/dhaba.jpg'), (2, 'Pizza Palace', 2, 'Best pizza in town', '456 Oak St', '555-0102', 4.3, '/static/images/pizza.jpg'), (3, 'Cool Drinks', 3, 'Refreshing beverages', '789 Pine St', '555-0103', 4.2, '/static/images/drinkshop.jpg'), (4, 'Sweet Treats', 4, 'Delicious desserts', '321 Elm St', '555-0104', 4.6, '/static/images/dessert.jpg')]
